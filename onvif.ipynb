# %%
from onvif import ONVIFCamera

cam = ONVIFCamera('192.168.1.10', 34567, 'bwnn', '3cm72e')

media = cam.create_media_service()
profiles = media.GetProfiles()

stream = media.GetStreamUri({
    'StreamSetup': {
        'Stream': 'RTP-Unicast',
        'Transport': {'Protocol': 'RTSP'}
    },
    'ProfileToken': profiles[0].token
})

print(stream.Uri)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/urllib3/connection.py:571, in HTTPConnection.getresponse(self)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#
# File ~/.pyenv/versions/3.12.8/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File ~/.pyenv/versions/3.12.8/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File ~/.pyenv/versions/3.12.8/lib/python3.12/http/client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/urllib3/util/retry.py:490, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     489 if read is False or method is None or not self._is_method_retryable(method):
# --> 490     raise reraise(type(error), error, _stacktrace)
#     491 elif read is not None:
#
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/urllib3/util/util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/urllib3/connection.py:571, in HTTPConnection.getresponse(self)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#
# File ~/.pyenv/versions/3.12.8/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File ~/.pyenv/versions/3.12.8/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File ~/.pyenv/versions/3.12.8/lib/python3.12/http/client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/onvif/client.py:23, in safe_func.<locals>.wrapped(*args, **kwargs)
#      22 try:
# ---> 23     return func(*args, **kwargs)
#      24 except Exception as err:
#      25     #print('Ouuups: err =', err, ', func =', func, ', args =', args, ', kwargs =', kwargs)
#
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/onvif/client.py:153, in ONVIFService.service_wrapper.<locals>.wrapped(params, callback)
#     152 else:
# --> 153     return call(params, callback)
#
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/onvif/client.py:140, in ONVIFService.service_wrapper.<locals>.wrapped.<locals>.call(params, callback)
#     139 try:
# --> 140     ret = func(**params)
#     141 except TypeError:
#     142     #print('### func =', func, '### params =', params, '### type(params) =', type(params))
#
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/zeep/proxy.py:46, in OperationProxy.__call__(self, *args, **kwargs)
#      44     kwargs["_soapheaders"] = soap_headers
# ---> 46 return self._proxy._binding.send(
#      47     self._proxy._client,
#      48     self._proxy._binding_options,
#      49     self._op_name,
#      50     args,
#      51     kwargs,
#      52 )
#
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/zeep/wsdl/bindings/soap.py:127, in SoapBinding.send(self, client, options, operation, args, kwargs)
#     123 envelope, http_headers = self._create(
#     124     operation, args, kwargs, client=client, options=options
#     125 )
# --> 127 response = client.transport.post_xml(options["address"], envelope, http_headers)
#     129 operation_obj = self.get(operation)
#
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/zeep/transports.py:118, in Transport.post_xml(self, address, envelope, headers)
#     117 message = etree_to_string(envelope)
# --> 118 return self.post(address, message, headers)
#
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/zeep/transports.py:84, in Transport.post(self, address, message, headers)
#      82     self.logger.debug("HTTP Post to %s:\n%s", address, log_message)
# ---> 84 response = self.session.post(
#      85     address, data=message, headers=headers, timeout=self.operation_timeout
#      86 )
#      88 if self.logger.isEnabledFor(logging.DEBUG):
#
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/requests/sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     627 r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629 :param url: URL for the new :class:`Request` object.
#    (...)    634 :rtype: requests.Response
#     635 """
# --> 637 return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/requests/adapters.py:659, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     658 except (ProtocolError, OSError) as err:
# --> 659     raise ConnectionError(err, request=request)
#     661 except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ONVIFError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 from onvif import ONVIFCamera
# ----> 3 cam = ONVIFCamera('192.168.1.10', 34567, 'bwnn', '3cm72e')
#       5 media = cam.create_media_service()
#       6 profiles = media.GetProfiles()
#
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/onvif/client.py:216, in ONVIFCamera.__init__(self, host, port, user, passwd, wsdl_dir, encrypt, daemon, no_cache, adjust_time, transport)
#     213 self.services_lock = RLock()
#     215 # Set xaddrs
# --> 216 self.update_xaddrs()
#     218 self.to_dict = ONVIFService.to_dict
#
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/onvif/client.py:233, in ONVIFCamera.update_xaddrs(self)
#     231 # Get XAddr of services on the device
#     232 self.xaddrs = { }
# --> 233 capabilities = self.devicemgmt.GetCapabilities({'Category': 'All'})
#     234 for name in capabilities:
#     235     capability = capabilities[name]
#
# File ~/projects/rl/rl_project_sac/.venv/lib/python3.12/site-packages/onvif/client.py:26, in safe_func.<locals>.wrapped(*args, **kwargs)
#      23     return func(*args, **kwargs)
#      24 except Exception as err:
#      25     #print('Ouuups: err =', err, ', func =', func, ', args =', args, ', kwargs =', kwargs)
# ---> 26     raise ONVIFError(err)
#
# ONVIFError: Unknown error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
